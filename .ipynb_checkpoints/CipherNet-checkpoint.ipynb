# %% [markdown]
# # CipherNet
#
# ### Objective
# ##### To embed a message into an image by manipulating some pixels such that the cipher is an image used to encrypt and decrypt the message.
#
# ### Tools
# ##### NumPy, Tensorflow-Keras, Matplotlib, Pillow and Resize-Image
#
# ### Procedure
#
# - `Designing` and training a neural network comprising of encoder and decoder
# - `Encoder` converts message into tokenized text and embeds it into an image.
# - `Decoder` takes the encoded image and deciphers the tokenized text.
# - `Training` is done using randomly generated images and texts so that the network can function with any type of images.

# %% [markdown]
# #### Mounting google drive to my VM on colab

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /gdrive

# %%
cd /gdrive/'My Drive'/CipherNet
# Out:
# /gdrive/My Drive/CryptoNet

# %%
# !pip install python-resize-image
# Out:
# Collecting python-resize-image
#   Downloading https://files.pythonhosted.org/packages/bc/89/008481c95551992e1a77503eba490b75fd17c0a98e33dd4dc39e0b99e5e8/python_resize_image-1.1.19-py2.py3-none-any.whl
# Requirement already satisfied: Pillow>=5.1.0 in /usr/local/lib/python3.6/dist-packages (from python-resize-image) (7.0.0)
# Requirement already satisfied: requests>=2.19.1 in /usr/local/lib/python3.6/dist-packages (from python-resize-image) (2.23.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.1->python-resize-image) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.1->python-resize-image) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.1->python-resize-image) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.19.1->python-resize-image) (3.0.4)
# Installing collected packages: python-resize-image
# Successfully installed python-resize-image-1.1.19

# %% [markdown]
# #### Importing necessary libraries

# %%
import numpy as np
from tensorflow.keras.models import *
from tensorflow.keras.metrics import *
from tensorflow.keras.layers import *
from tensorflow.keras.preprocessing.image import img_to_array, load_img
from tensorflow.keras.losses import *
from tensorflow.keras.callbacks import *
from PIL import Image
from resizeimage import resizeimage
import matplotlib.pyplot as plt

# %% [markdown]
# #### Defining sizes for the image and message

# %%
image_shape = (100, 100, 3)
sentence_length = 100
words_maximum = 256

# %% [markdown]
# #### Defining Data Generator

# %%
def data_generator(shape_img, length_sentence, maximum_words, batch_size=32):
    while True:
        image_x = np.zeros((batch_size, shape_img[0], shape_img[1], shape_img[2]))
        sentence_x = np.zeros((batch_size, length_sentence))
        image_y = np.zeros((batch_size, shape_img[0], shape_img[1], shape_img[2]))
        sentence_y = np.zeros((batch_size, length_sentence, maximum_words))
        for i in range(batch_size):
            # Creating random image using randint
            img = np.random.randint(0, 256, shape_img) / 255.0
            # Creating random sentence using randint
            sentence = np.random.randint(0, maximum_words, length_sentence)
            # Performing one hot encoding on the random sentence
            one_hot_encoding = np.zeros((len(sentence),maximum_words))
            for j,v in enumerate(sentence):
                one_hot_encoding[j, v] = 1
            image_x[i] = img
            sentence_x[i] = sentence
            image_y[i] = img
            sentence_y[i] = one_hot_encoding
        yield [image_x, sentence_x], [image_y, sentence_y]

# %% [markdown]
# #### Defining Model

# %%
def get_model(shape_img, length_sentence, maximum_words):
    # Input image with size (100,100)
    image_input = Input(shape_img)
    # Input sentence with text length 100
    sentence_input = Input((length_sentence,))
    # Embedding the input sentence with output dimension as 100
    embedded_sentence = Embedding(maximum_words, 100)(sentence_input)
    # Embedding each character of sentence to a new space with 100 dimension.
    # Shape of embedded sequence (100, 100)
    # Reshaping the embedding as (100, 100, 1)
    flat_embedded_sentence = Flatten()(embedded_sentence)
    flat_embedded_sentence = Reshape((shape_img[0], shape_img[1], 1))(flat_embedded_sentence)
    # 2D convolutional layer with kernel size (1,1) and 20 filters activated by ReLu
    transformed_image_input = Conv2D(20, 1, activation="relu")(image_input)
    # Attaching embedded sequence to the image in 3rd axis 
    # Shape of tensor (100, 100, 21)
    encoded_input = Concatenate(axis=-1)([flat_embedded_sentence, transformed_image_input])
    # Inputting the embedded image to a (1, 1) conv layer with one filter
    image_output = Conv2D(3, 1, activation='relu', name='image_reconstruction')(encoded_input)
    # Decoder model
    decoder = Sequential(name="sentence_reconstruction")
    decoder.add(Conv2D(1, 1, input_shape=(100, 100, 3)))
    decoder.add(Reshape((length_sentence, 100)))
    decoder.add(TimeDistributed(Dense(maximum_words, activation="softmax")))
    sentence_output = decoder(image_output)
    # Training specifications
    model = Model(inputs=[image_input, sentence_input], outputs=[image_output, sentence_output])
    model.compile('adam', loss=[mean_absolute_error, categorical_crossentropy],
                  metrics={'sentence_reconstruction': categorical_accuracy})
    encoder = Model(inputs=[image_input, sentence_input], outputs=[image_output])
    return model, encoder, decoder

# %% [markdown]
# #### Training specifications

# %%
gen = data_generator(image_shape, sentence_length, words_maximum, 64)
model, encoder, decoder = get_model(image_shape, sentence_length, words_maximum)
try:
    model.load_weights("best_weights.h5")
except:
    model.fit(gen, epochs=512, steps_per_epoch=348, callbacks=[
        ModelCheckpoint("best_weights.h5",monitor="loss",
                        verbose=1,
                        save_weights_only=True,
                        save_best_only=True)]
    )
# Out:
# Epoch 1/512
# 348/348 [==============================] - ETA: 0s - loss: 2.2531 - image_reconstruction_loss: 0.3029 - sentence_reconstruction_loss: 1.9502 - sentence_reconstruction_categorical_accuracy: 0.8069
# Epoch 00001: loss improved from inf to 2.25306, saving model to best_weights.h5
# 348/348 [==============================] - 25s 71ms/step - loss: 2.2531 - image_reconstruction_loss: 0.3029 - sentence_reconstruction_loss: 1.9502 - sentence_reconstruction_categorical_accuracy: 0.8069
# Epoch 2/512
# 348/348 [==============================] - ETA: 0s - loss: 0.2747 - image_reconstruction_loss: 0.2639 - sentence_reconstruction_loss: 0.0107 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00002: loss improved from 2.25306 to 0.27465, saving model to best_weights.h5
# 348/348 [==============================] - 25s 71ms/step - loss: 0.2747 - image_reconstruction_loss: 0.2639 - sentence_reconstruction_loss: 0.0107 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 3/512
# 348/348 [==============================] - ETA: 0s - loss: 0.2673 - image_reconstruction_loss: 0.2607 - sentence_reconstruction_loss: 0.0066 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00003: loss improved from 0.27465 to 0.26732, saving model to best_weights.h5
# 348/348 [==============================] - 25s 71ms/step - loss: 0.2673 - image_reconstruction_loss: 0.2607 - sentence_reconstruction_loss: 0.0066 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 4/512
# 348/348 [==============================] - ETA: 0s - loss: 0.2618 - image_reconstruction_loss: 0.2561 - sentence_reconstruction_loss: 0.0057 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00004: loss improved from 0.26732 to 0.26179, saving model to best_weights.h5
# 348/348 [==============================] - 24s 70ms/step - loss: 0.2618 - image_reconstruction_loss: 0.2561 - sentence_reconstruction_loss: 0.0057 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 5/512
# 348/348 [==============================] - ETA: 0s - loss: 0.2566 - image_reconstruction_loss: 0.2514 - sentence_reconstruction_loss: 0.0052 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00005: loss improved from 0.26179 to 0.25661, saving model to best_weights.h5
# 348/348 [==============================] - 24s 69ms/step - loss: 0.2566 - image_reconstruction_loss: 0.2514 - sentence_reconstruction_loss: 0.0052 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 6/512
# 348/348 [==============================] - ETA: 0s - loss: 0.2519 - image_reconstruction_loss: 0.2471 - sentence_reconstruction_loss: 0.0048 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00006: loss improved from 0.25661 to 0.25191, saving model to best_weights.h5
# 348/348 [==============================] - 24s 69ms/step - loss: 0.
-04 - sentence_reconstruction_categorical_accuracy: 0.9999
# Epoch 499/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1753 - image_reconstruction_loss: 0.1752 - sentence_reconstruction_loss: 1.5933e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00499: loss did not improve from 0.17520
# 348/348 [==============================] - 23s 67ms/step - loss: 0.1753 - image_reconstruction_loss: 0.1752 - sentence_reconstruction_loss: 1.5933e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 500/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1754 - image_reconstruction_loss: 0.1752 - sentence_reconstruction_loss: 1.6406e-04 - sentence_reconstruction_categorical_accuracy: 0.9999
# Epoch 00500: loss did not improve from 0.17520
# 348/348 [==============================] - 24s 68ms/step - loss: 0.1754 - image_reconstruction_loss: 0.1752 - sentence_reconstruction_loss: 1.6406e-04 - sentence_reconstruction_categorical_accuracy: 0.9999
# Epoch 501/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1755 - image_reconstruction_loss: 0.1754 - sentence_reconstruction_loss: 1.6754e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00501: loss did not improve from 0.17520
# 348/348 [==============================] - 24s 68ms/step - loss: 0.1755 - image_reconstruction_loss: 0.1754 - sentence_reconstruction_loss: 1.6754e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 502/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1756 - image_reconstruction_loss: 0.1754 - sentence_reconstruction_loss: 1.5877e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00502: loss did not improve from 0.17520
# 348/348 [==============================] - 24s 68ms/step - loss: 0.1756 - image_reconstruction_loss: 0.1754 - sentence_reconstruction_loss: 1.5877e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 503/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1756 - image_reconstruction_loss: 0.1754 - sentence_reconstruction_loss: 1.4845e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00503: loss did not improve from 0.17520
# 348/348 [==============================] - 24s 68ms/step - loss: 0.1756 - image_reconstruction_loss: 0.1754 - sentence_reconstruction_loss: 1.4845e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 504/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1753 - image_reconstruction_loss: 0.1751 - sentence_reconstruction_loss: 1.6927e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00504: loss did not improve from 0.17520
# 348/348 [==============================] - 23s 67ms/step - loss: 0.1753 - image_reconstruction_loss: 0.1751 - sentence_reconstruction_loss: 1.6927e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 505/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1753 - image_reconstruction_loss: 0.1751 - sentence_reconstruction_loss: 1.5688e-04 - sentence_reconstruction_categorical_accuracy: 0.9999
# Epoch 00505: loss did not improve from 0.17520
# 348/348 [==============================] - 23s 67ms/step - loss: 0.1753 - image_reconstruction_loss: 0.1751 - sentence_reconstruction_loss: 1.5688e-04 - sentence_reconstruction_categorical_accuracy: 0.9999
# Epoch 506/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1753 - image_reconstruction_loss: 0.1751 - sentence_reconstruction_loss: 1.4948e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00506: loss did not improve from 0.17520
# 348/348 [==============================] - 24s 68ms/step - loss: 0.1753 - image_reconstruction_loss: 0.1751 - sentence_reconstruction_loss: 1.4948e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 507/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1754 - image_reconstruction_loss: 0.1752 - sentence_reconstruction_loss: 1.5964e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00507: loss did not improve from 0.17520
# 348/348 [==============================] - 24s 68ms/step - loss: 0.1754 - image_reconstruction_loss: 0.1752 - sentence_reconstruction_loss: 1.5964e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 508/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1753 - image_reconstruction_loss: 0.1751 - sentence_reconstruction_loss: 1.7714e-04 - sentence_reconstruction_categorical_accuracy: 0.9999
# Epoch 00508: loss did not improve from 0.17520
# 348/348 [==============================] - 24s 68ms/step - loss: 0.1753 - image_reconstruction_loss: 0.1751 - sentence_reconstruction_loss: 1.7714e-04 - sentence_reconstruction_categorical_accuracy: 0.9999
# Epoch 509/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1754 - image_reconstruction_loss: 0.1753 - sentence_reconstruction_loss: 1.7723e-04 - sentence_reconstruction_categorical_accuracy: 0.9999
# Epoch 00509: loss did not improve from 0.17520
# 348/348 [==============================] - 24s 68ms/step - loss: 0.1754 - image_reconstruction_loss: 0.1753 - sentence_reconstruction_loss: 1.7723e-04 - sentence_reconstruction_categorical_accuracy: 0.9999
# Epoch 510/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1754 - image_reconstruction_loss: 0.1752 - sentence_reconstruction_loss: 1.5929e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00510: loss did not improve from 0.17520
# 348/348 [==============================] - 24s 68ms/step - loss: 0.1754 - image_reconstruction_loss: 0.1752 - sentence_reconstruction_loss: 1.5929e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 511/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1754 - image_reconstruction_loss: 0.1752 - sentence_reconstruction_loss: 1.8084e-04 - sentence_reconstruction_categorical_accuracy: 0.9999
# Epoch 00511: loss did not improve from 0.17520
# 348/348 [==============================] - 24s 69ms/step - loss: 0.1754 - image_reconstruction_loss: 0.1752 - sentence_reconstruction_loss: 1.8084e-04 - sentence_reconstruction_categorical_accuracy: 0.9999
# Epoch 512/512
# 348/348 [==============================] - ETA: 0s - loss: 0.1755 - image_reconstruction_loss: 0.1753 - sentence_reconstruction_loss: 1.6423e-04 - sentence_reconstruction_categorical_accuracy: 1.0000
# Epoch 00512: loss did not improve from 0.17520
# 348/348 [==============================] - 24s 68ms/step - loss: 0.1755 - image_reconstruction_loss: 0.1753 - sentence_reconstruction_loss: 1.6423e-04 - sentence_reconstruction_categorical_accuracy: 1.0000

# %% [markdown]
# #### Image Resizing function

# %%
def adjust_size_image(img,d1,d2):
  with open(img, 'r+b') as f:
    with Image.open(f) as image:
      cover = resizeimage.resize_cover(image, [d1, d2])
      return cover

# %% [markdown]
# #### Choosing the image to send the secret message

# %%
img = np.expand_dims(img_to_array(adjust_size_image("The_Riddler.jpg",100,100)) / 255.0, axis=0)

# %% [markdown]
# #### ASCII Encoding the raw message

# %%
raw_message = 'Riddle me this- "What has no hands but might knock on your door, and you better open it if it does?"'
ascii_message = np.zeros((1, sentence_length))
for i, a in enumerate(raw_message.encode("ascii")):
    ascii_message[0, i] = a

# %% [markdown]
# #### Embedding the message into the image using encoder

# %%
embedded_image = encoder.predict([img, ascii_message])

# %% [markdown]
# #### Predicting the message from embedded image using decoder

# %%
prediction = decoder.predict(embedded_image)

# %% [markdown]
# #### Displaying the original image and embedded image(cipher)

# %%
width=20
height=20
axes=[]
fig=plt.figure()
axes.append( fig.add_subplot(1, 2, 1) )
axes[-1].set_title("Original Image", fontsize=12)  
plt.imshow((img[0,:,:,:]* 255).astype(np.uint8))
axes.append( fig.add_subplot(1, 2, 2) )
axes[-1].set_title("Image embedded with message", fontsize=12)  
plt.imshow((embedded_image[0,:,:,:]* 255).astype(np.uint8))
fig.tight_layout()    
plt.show()

# %% [markdown]
# #### ASCII Decoding the message extracted from the embedded image

# %%
print(''.join(chr(int(a)) for a in prediction[0].argmax(-1)))
# Out:
# Riddle me this- "What has no hands but might knock on your door, and you better open it if it does?"
